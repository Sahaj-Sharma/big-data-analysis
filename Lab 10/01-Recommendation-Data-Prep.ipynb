# %% [markdown]
# # Recommendation - Data Preparation 🎬

# %% [markdown]
# ---

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/1200/0*ePGWILY6GyplT-nn" />

# %% [markdown]
# ---

# %% [markdown]
# In the next few challenges, you will build a powerful **movie recommender**.
#
# We will use the open-source library [LightFM](https://github.com/lyst/lightfm) which provides easy python implementation of **hybrid** recommendation engines.
#
# In this first part, we will prepare the data in order to train efficiently of the model.
#
# We let you load the data `movies` and `ratings` downloaded from the **small** [movielens dataset](https://grouplens.org/datasets/movielens/).

# %%
### TODO: Load the movies and ratings datasets
import pandas as pd

movies = pd.read_csv("ml-latest-small/movies.csv")
ratings = pd.read_csv("ml-latest-small/ratings.csv")

print(movies.head())
print(ratings.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# **Q1**. What are the different types of recommendation models? Explain briefly with your own words the differences between them.

# %% [markdown]
# Different types of recommendation models:
# 1. Content-based recommendation:
# This system recommends based on similarity between user interest and the description of the item.
#
#
# 2. Rating-based recommendation: It uses nearest neighbour approach and gives either user-based or item-based recommendations using a rating matrix.
#
# User-based: Uses ratings and items liked by similar users as recommendation.
# Item-based: Finds items similar to user's liking and recommends them.
#
# 3. Clustering-based recommendation: Classifies users into clusters based on similar ratings to items and  then recommends the same thing to users belonging to the cluster.
#
# DIFFERENCE:
# Content-based recommendation is not depend on other users like the other two systems. It limits the ability to expand the user's existing interests. But it is not affected by less ratings as it depends upon the user.
#
# Rating-based recommendation uses other users' ratings on items for recommendation. It helps users find new interests. It accuracy is affected if items ratings are too few in number.
#
# Clustering-based recommendation creates clusters of people and hence is depend on other users. It is able to find new interesting items for users better than rating-based system but might lack in user-specific relevance unlike the other two systems.

# %% [markdown]
# **Q1bis**. What data is expected by the LightFM `fit` method? Especially, how does the train data should be organized, and what should be the type of the train dataset?

# %% [markdown]
# 1. The fit method expects a sparse matrix of user and item features that has 1 for positive interaction and -1 for negative interactions.
#
# 2. The train data should be organised as a sparse matrix of user ratings and user movies and the train dataset should be of integer type.

# %% [markdown]
# **Q2**. Explore `movies` and `ratings`, what do those datasets contain? How are they organized?

# %%
print(movies.shape)
print(movies.info())
movies.head()
# Out:
# (9742, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB
# None
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings["date_time"] = pd.to_datetime(ratings["timestamp"], unit='s')
print(ratings.shape)
print(ratings.info())
ratings.head()
# Out:
# (100836, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
#  4   date_time  100836 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 3.8 MB
# None
#    userId  movieId  rating  timestamp           date_time
# 0       1        1     4.0  964982703 2000-07-30 18:45:03
# 1       1        3     4.0  964981247 2000-07-30 18:20:47
# 2       1        6     4.0  964982224 2000-07-30 18:37:04
# 3       1       47     5.0  964983815 2000-07-30 19:03:35
# 4       1       50     5.0  964982931 2000-07-30 18:48:51

# %% [markdown]
# ---

# %% [markdown]
# ### Q3 & Q4 are optional
# > you can come back to it if you have time after having finished the whole project of the day

# %% [markdown]
# We created a few utils functions for you in `utils.py` script. Especially:
# - `threshold_interactions_df`:
# > Limit interactions df to minimum row and column interactions
#
# **Q3**. Open `src/utils.py` file, and have a look at the documentation of this function to understand its goal and how it works.
#
# Have a look the code to understand fully how it works. You should be familiar with everything.
#
# What does represent the variable `sparsity`? What is the range of values in which sparsity can be?

# %% [markdown]
# Threshold_interactiond_df takes the interaction matrix, and filters out any users or movies that don't have many reviews.
# The sparsity represents how empty (preportion of 0's) the matrix is.
# The values ranges between 0, when no users rate no movies, and 1 (100%) when all users rate all movies.

# %% [markdown]
# **Q4**. Create a new DataFrame `ratings_thresh`, that filters `ratings` with only:
# - users that rated strictly more than 4 movies
# - movies that have been rated at least 10 times
#
# How many users/movies remain in this new dataset?

# %%
from utils import threshold_interactions_df

ratings_thresh = threshold_interactions_df(
    df = ratings,
    row_name= 'userId',
    col_name='movieId',
    row_min=5,
    col_min=10
)
print("There remains",
      len(ratings_thresh.userId.unique()),
      "users and",
      len(ratings_thresh.movieId.unique()),
      "movies after performing threshold.")
# Out:
# Starting interactions info
# Number of rows: 610
# Number of cols: 9724
# Sparsity: 1.700%
# Ending interactions info
# Number of rows: 610
# Number of columns: 3650
# Sparsity: 4.055%
# There remains 610 users and 3650 movies after performing threshold.

# %% [markdown]
# **Q5**. In order to fit a [LightFM](https://lyst.github.io/lightfm/docs/home.html) model, we need to transform our Dataframe to a sparse matrix (cf. below). This is not straightforward so we included the function `df_to_matrix` in `utils.py`.
#
# > 🔦 **Hint**:  Sparse matrices are just **big matrices with a lot of zeros or empty values**.
# >
# > Existing tools (Pandas DataFrame, Numpy arrays for example) are not suitable for manipulating this kind of data. So we will use [Scipy sparse matrices](https://docs.scipy.org/doc/scipy-0.14.0/reference/sparse.html).
# >
# > It exists many different "types" of sparse matrices (CSC, CSR, COO, DIA, etc.). You don't need to know them. Just know that it corresponds to different formats with different methods of manipulation, slicing, indexing, etc.
#
# > 🔦 **Hint 2**:  By going from a DataFrame to a sparse matrix, you will lose the information of the ids (userId and movieId), you will only deal with indices (row number and column number). Therefore, the `df_to_matrix` function also returns dictionaries mapping indexes to ids (ex: uid_to_idx mapping userId to index of the matrix)
#
#
# Have a look at the util function documentation, and use it to create 5 new variables:
# - a final sparse matrix `ratings_matrix` (this will be the data used to train the model)
# - the following utils mappers:
#     - `uid_to_idx`
#     - `idx_to_uid`
#     - `mid_to_idx`
#     - `idx_to_mid`

# %%
from utils import df_to_matrix

ratings_matrix, uid_to_idx, idx_to_uid, mid_to_idx, idx_to_mid = df_to_matrix(
    df = ratings,
    row_name= 'userId',
    col_name='movieId'
)
ratings_matrix
# Out:
# <610x9724 sparse matrix of type '<class 'numpy.float64'>'
# 	with 100836 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Q6**.
# - On the one side, find what movies did the userId 4 rate?
#
# - On the other side, what is the value of `ratings_matrix` for:
#     - userId = 4 and movieId=1
#     - userId = 4 and movieId=2
#     - userId = 4 and movieId=21
#     - userId = 4 and movieId=32
#     - userId = 4 and movieId=126
#
# Conclude on the values signification in `ratings_matrix`

# %%
"""
print("Movies User 4 rated:")
ratings[ratings.userId == 4]
"""
movies.index = movies["movieId"]
uid_4_ratings = ratings_matrix[uid_to_idx[4]].tocoo()

print("Movies User 4 rated:")
print()

for movie_idx in uid_4_ratings.col:
    mid = idx_to_mid[movie_idx]
    print("Movie ID:", mid)
    print("Movie Title:",movies.loc[mid]["title"])
    print()
# Out:
# Movies User 4 rated:
#
# Movie ID: 47
# Movie Title: Seven (a.k.a. Se7en) (1995)
#
# Movie ID: 235
# Movie Title: Ed Wood (1994)
#
# Movie ID: 260
# Movie Title: Star Wars: Episode IV - A New Hope (1977)
#
# Movie ID: 296
# Movie Title: Pulp Fiction (1994)
#
# Movie ID: 441
# Movie Title: Dazed and Confused (1993)
#
# Movie ID: 457
# Movie Title: Fugitive, The (1993)
#
# Movie ID: 553
# Movie Title: Tombstone (1993)
#
# Movie ID: 593
# Movie Title: Silence of the Lambs, The (1991)
#
# Movie ID: 608
# Movie Title: Fargo (1996)
#
# Movie ID: 648
# Movie Title: Mission: Impossible (1996)
#
# Movie ID: 919
# Movie Title: Wizard of Oz, The (1939)
#
# Movie ID: 1025
# Movie Title: Sword in the Stone, The (1963)
#
# Movie ID: 1060
# Movie Title: Swingers (1996)
#
# Movie ID: 1073
# Movie Title: Willy Wonka & the Chocolate Factory (1971)
#
# Movie ID: 1080
# Movie Title: Monty Python's Life of Brian (1979)
#
# Movie ID: 1136
# Movie Title: Monty Python and the Holy Grail (1975)
#
# Movie ID: 1196
# Movie Title: Star Wars: Episode V - The Empire Strikes Back (1980)
#
# Movie ID: 1197
# Movie Title: Princess Bride, The (1987)
#
# Movie ID: 1198
# Movie Title: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)
#
# Movie ID: 1213
# Movie Title: Goodfellas (1990)
#
# Movie ID: 1219
# Movie Title: Psycho (1960)
#
# Movie ID: 1265
# Movie Title: Groundhog Day (1993)
#
# Movie ID: 1282
# Movie Title: Fantasia (1940)
#
# Movie ID: 1291
# Movie Title: Indiana Jones and the Last Crusade (1989)
#
# Movie ID: 1500
# Movie Title: Grosse Pointe Blank (1997)
#
# Movie ID: 1517
# Movie Title: Austin Powers: International Man of Mystery (1997)
#
# Movie ID: 1580
# Movie Title: Men in Black (a.k.a. MIB) (1997)
#
# Movie ID: 1617
# Movie Title: L.A. Confidential (1997)
#
# Movie ID: 1732
# Movie Title: Big Lebowski, The (1998)
#
# Movie ID: 1967
# Movie Title: Labyrinth (1986)
#
# Movie ID: 2078
# Movie Title: Jungle Book, The (1967)
#
# Movie ID: 2174
# Movie Title: Beetlejuice (1988)
#
# Movie ID: 2395
# Movie Title: Rushmore (1998)
#
# Movie ID: 2406
# Movie Title: Romancing the Stone (1984)
#
# Movie ID: 2571
# Movie Title: Matrix, The (1999)
#
# Movie ID: 2628
# Movie Title: Star Wars: Episode I - The Phantom Menace (1999)
#
# Movie ID: 2692
# Movie Title: Run Lola Run (Lola rennt) (1998)
#
# Movie ID: 2858
# Movie Title: American Beauty (1999)
#
# Movie ID: 2959
# Movie Title: Fight Club (1999)
#
# Movie ID: 2997
# Movie Title: Being John Malkovich (1999)
#
# Movie ID: 3033
# Movie Title: Spaceballs (1987)
#
# Movie ID: 3176
# Movie Title: Talented Mr. Ripley, The (1999)
#
# Movie ID: 3386
# Movie Title: JFK (1991)
#
# Movie ID: 3489
# Movie Title: Hook (1991)
#
# Movie ID: 3809
# Movie Title: What About Bob? (1991)
#
# Movie ID: 1704
# Movie Title: Good Will Hunting (1997)
#
# Movie ID: 914
# Movie Title: My Fair Lady (1964)
#
# Movie ID: 21
# Movie Title: Get Shorty (1995)
#
# Movie ID: 32
# Movie Title: Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
#
# Movie ID: 45
# Movie Title: To Die For (1995)
#
# Movie ID: 52
# Movie Title: Mighty Aphrodite (1995)
#
# Movie ID: 58
# Movie Title: Postman, The (Postino, Il) (1994)
#
# Movie ID: 106
# Movie Title: Nobody Loves Me (Keiner liebt mich) (1994)
#
# Movie ID: 125
# Movie Title: Flirting With Disaster (1996)
#
# Movie ID: 126
# Movie Title: NeverEnding Story III, The (1994)
#
# Movie ID: 162
# Movie Title: Crumb (1994)
#
# Movie ID: 171
# Movie Title: Jeffrey (1995)
#
# Movie ID: 176
# Movie Title: Living in Oblivion (1995)
#
# Movie ID: 190
# Movie Title: Safe (1995)
#
# Movie ID: 215
# Movie Title: Before Sunrise (1995)
#
# Movie ID: 222
# Movie Title: Circle of Friends (1995)
#
# Movie ID: 232
# Movie Title: Eat Drink Man Woman (Yin shi nan nu) (1994)
#
# Movie ID: 247
# Movie Title: Heavenly Creatures (1994)
#
# Movie ID: 265
# Movie Title: Like Water for Chocolate (Como agua para chocolate) (1992)
#
# Movie ID: 319
# Movie Title: Shallow Grave (1994)
#
# Movie ID: 342
# Movie Title: Muriel's Wedding (1994)
#
# Movie ID: 345
# Movie Title: Adventures of Priscilla, Queen of the Desert, The (1994)
#
# Movie ID: 348
# Movie Title: Bullets Over Broadway (1994)
#
# Movie ID: 351
# Movie Title: Corrina, Corrina (1994)
#
# Movie ID: 357
# Movie Title: Four Weddings and a Funeral (1994)
#
# Movie ID: 368
# Movie Title: Maverick (1994)
#
# Movie ID: 417
# Movie Title: Barcelona (1994)
#
# Movie ID: 450
# Movie Title: With Honors (1994)
#
# Movie ID: 475
# Movie Title: In the Name of the Father (1993)
#
# Movie ID: 492
# Movie Title: Manhattan Murder Mystery (1993)
#
# Movie ID: 509
# Movie Title: Piano, The (1993)
#
# Movie ID: 538
# Movie Title: Six Degrees of Separation (1993)
#
# Movie ID: 539
# Movie Title: Sleepless in Seattle (1993)
#
# Movie ID: 588
# Movie Title: Aladdin (1992)
#
# Movie ID: 595
# Movie Title: Beauty and the Beast (1991)
#
# Movie ID: 599
# Movie Title: Wild Bunch, The (1969)
#
# Movie ID: 708
# Movie Title: Truth About Cats & Dogs, The (1996)
#
# Movie ID: 759
# Movie Title: Maya Lin: A Strong Clear Vision (1994)
#
# Movie ID: 800
# Movie Title: Lone Star (1996)
#
# Movie ID: 892
# Movie Title: Twelfth Night (1996)
#
# Movie ID: 898
# Movie Title: Philadelphia Story, The (1940)
#
# Movie ID: 899
# Movie Title: Singin' in the Rain (1952)
#
# Movie ID: 902
# Movie Title: Breakfast at Tiffany's (1961)
#
# Movie ID: 904
# Movie Title: Rear Window (1954)
#
# Movie ID: 908
# Movie Title: North by Northwest (1959)
#
# Movie ID: 910
# Movie Title: Some Like It Hot (1959)
#
# Movie ID: 912
# Movie Title: Casablanca (1942)
#
# Movie ID: 920
# Movie Title: Gone with the Wind (1939)
#
# Movie ID: 930
# Movie Title: Notorious (1946)
#
# Movie ID: 937
# Movie Title: Love in the Afternoon (1957)
#
# Movie ID: 1046
# Movie Title: Beautiful Thing (1996)
#
# Movie ID: 1057
# Movie Title: Everyone Says I Love You (1996)
#
# Movie ID: 1077
# Movie Title: Sleeper (1973)
#
# Movie ID: 1079
# Movie Title: Fish Called Wanda, A (1988)
#
# Movie ID: 1084
# Movie Title: Bonnie and Clyde (1967)
#
# Movie ID: 1086
# Movie Title: Dial M for Murder (1954)
#
# Movie ID: 1094
# Movie Title: Crying Game, The (1992)
#
# Movie ID: 1103
# Movie Title: Rebel Without a Cause (1955)
#
# Movie ID: 1179
# Movie Title: Grifters, The (1990)
#
# Movie ID: 1183
# Movie Title: English Patient, The (1996)
#
# Movie ID: 1188
# Movie Title: Strictly Ballroom (1992)
#
# Movie ID: 1199
# Movie Title: Brazil (1985)
#
# Movie ID: 1203
# Movie Title: 12 Angry Men (1957)
#
# Movie ID: 1211
# Movie Title: Wings of Desire (Himmel über Berlin, Der) (1987)
#
# Movie ID: 1225
# Movie Title: Amadeus (1984)
#
# Movie ID: 1250
# Movie Title: Bridge on the River Kwai, The (1957)
#
# Movie ID: 1259
# Movie Title: Stand by Me (1986)
#
# Movie ID: 1266
# Movie Title: Unforgiven (1992)
#
# Movie ID: 1279
# Movie Title: Night on Earth (1991)
#
# Movie ID: 1283
# Movie Title: High Noon (1952)
#
# Movie ID: 1288
# Movie Title: This Is Spinal Tap (1984)
#
# Movie ID: 1304
# Movie Title: Butch Cassidy and the Sundance Kid (1969)
#
# Movie ID: 1391
# Movie Title: Mars Attacks! (1996)
#
# Movie ID: 1449
# Movie Title: Waiting for Guffman (1996)
#
# Movie ID: 1466
# Movie Title: Donnie Brasco (1997)
#
# Movie ID: 1597
# Movie Title: Conspiracy Theory (1997)
#
# Movie ID: 1641
# Movie Title: Full Monty, The (1997)
#
# Movie ID: 1719
# Movie Title: Sweet Hereafter, The (1997)
#
# Movie ID: 1733
# Movie Title: Afterglow (1997)
#
# Movie ID: 1734
# Movie Title: My Life in Pink (Ma vie en rose) (1997)
#
# Movie ID: 1834
# Movie Title: Spanish Prisoner, The (1997)
#
# Movie ID: 1860
# Movie Title: Character (Karakter) (1997)
#
# Movie ID: 1883
# Movie Title: Bulworth (1998)
#
# Movie ID: 1885
# Movie Title: Opposite of Sex, The (1998)
#
# Movie ID: 1892
# Movie Title: Perfect Murder, A (1998)
#
# Movie ID: 1895
# Movie Title: Can't Hardly Wait (1998)
#
# Movie ID: 1907
# Movie Title: Mulan (1998)
#
# Movie ID: 1914
# Movie Title: Smoke Signals (1998)
#
# Movie ID: 1916
# Movie Title: Buffalo '66 (a.k.a. Buffalo 66) (1998)
#
# Movie ID: 1923
# Movie Title: There's Something About Mary (1998)
#
# Movie ID: 1947
# Movie Title: West Side Story (1961)
#
# Movie ID: 1966
# Movie Title: Metropolitan (1990)
#
# Movie ID: 1968
# Movie Title: Breakfast Club, The (1985)
#
# Movie ID: 2019
# Movie Title: Seven Samurai (Shichinin no samurai) (1954)
#
# Movie ID: 2076
# Movie Title: Blue Velvet (1986)
#
# Movie ID: 2109
# Movie Title: Jerk, The (1979)
#
# Movie ID: 2145
# Movie Title: Pretty in Pink (1986)
#
# Movie ID: 2150
# Movie Title: Gods Must Be Crazy, The (1980)
#
# Movie ID: 2186
# Movie Title: Strangers on a Train (1951)
#
# Movie ID: 2203
# Movie Title: Shadow of a Doubt (1943)
#
# Movie ID: 2204
# Movie Title: Saboteur (1942)
#
# Movie ID: 2282
# Movie Title: Pecker (1998)
#
# Movie ID: 2324
# Movie Title: Life Is Beautiful (La Vita è bella) (1997)
#
# Movie ID: 2336
# Movie Title: Elizabeth (1998)
#
# Movie ID: 2351
# Movie Title: Nights of Cabiria (Notti di Cabiria, Le) (1957)
#
# Movie ID: 2359
# Movie Title: Waking Ned Devine (a.k.a. Waking Ned) (1998)
#
# Movie ID: 2390
# Movie Title: Little Voice (1998)
#
# Movie ID: 2467
# Movie Title: Name of the Rose, The (Name der Rose, Der) (1986)
#
# Movie ID: 2583
# Movie Title: Cookie's Fortune (1999)
#
# Movie ID: 2599
# Movie Title: Election (1999)
#
# Movie ID: 2683
# Movie Title: Austin Powers: The Spy Who Shagged Me (1999)
#
# Movie ID: 2712
# Movie Title: Eyes Wide Shut (1999)
#
# Movie ID: 2762
# Movie Title: Sixth Sense, The (1999)
#
# Movie ID: 2763
# Movie Title: Thomas Crown Affair, The (1999)
#
# Movie ID: 2770
# Movie Title: Bowfinger (1999)
#
# Movie ID: 2791
# Movie Title: Airplane! (1980)
#
# Movie ID: 2843
# Movie Title: Black Cat, White Cat (Crna macka, beli macor) (1998)
#
# Movie ID: 2874
# Movie Title: Pajama Game, The (1957)
#
# Movie ID: 2921
# Movie Title: High Plains Drifter (1973)
#
# Movie ID: 2926
# Movie Title: Hairspray (1988)
#
# Movie ID: 2973
# Movie Title: Crimes and Misdemeanors (1989)
#
# Movie ID: 3044
# Movie Title: Dead Again (1991)
#
# Movie ID: 3060
# Movie Title: Commitments, The (1991)
#
# Movie ID: 3079
# Movie Title: Mansfield Park (1999)
#
# Movie ID: 3083
# Movie Title: All About My Mother (Todo sobre mi madre) (1999)
#
# Movie ID: 3160
# Movie Title: Magnolia (1999)
#
# Movie ID: 3175
# Movie Title: Galaxy Quest (1999)
#
# Movie ID: 3204
# Movie Title: Boys from Brazil, The (1978)
#
# Movie ID: 3255
# Movie Title: League of Their Own, A (1992)
#
# Movie ID: 3317
# Movie Title: Wonder Boys (2000)
#
# Movie ID: 3358
# Movie Title: Defending Your Life (1991)
#
# Movie ID: 3365
# Movie Title: Searchers, The (1956)
#
# Movie ID: 3408
# Movie Title: Erin Brockovich (2000)
#
# Movie ID: 3481
# Movie Title: High Fidelity (2000)
#
# Movie ID: 3508
# Movie Title: Outlaw Josey Wales, The (1976)
#
# Movie ID: 3538
# Movie Title: East is East (1999)
#
# Movie ID: 3591
# Movie Title: Mr. Mom (1983)
#
# Movie ID: 3788
# Movie Title: Blow-Up (Blowup) (1966)
#
# Movie ID: 3851
# Movie Title: I'm the One That I Want (2000)
#
# Movie ID: 3897
# Movie Title: Almost Famous (2000)
#
# Movie ID: 3911
# Movie Title: Best in Show (2000)
#
# Movie ID: 3967
# Movie Title: Billy Elliot (2000)
#
# Movie ID: 3996
# Movie Title: Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)
#
# Movie ID: 4002
# Movie Title: Planes, Trains & Automobiles (1987)
#
# Movie ID: 4014
# Movie Title: Chocolat (2000)
#
# Movie ID: 4020
# Movie Title: Gift, The (2000)
#
# Movie ID: 4021
# Movie Title: Before Night Falls (2000)
#
# Movie ID: 4027
# Movie Title: O Brother, Where Art Thou? (2000)
#
# Movie ID: 4029
# Movie Title: State and Main (2000)
#
# Movie ID: 4033
# Movie Title: Thirteen Days (2000)
#
# Movie ID: 4034
# Movie Title: Traffic (2000)
#
# Movie ID: 4074
# Movie Title: Legend of Rita, The (Stille nach dem Schuß, Die) (1999)
#
# Movie ID: 4121
# Movie Title: Innerspace (1987)
#
# Movie ID: 4144
# Movie Title: In the Mood For Love (Fa yeung nin wa) (2000)
#
# Movie ID: 4166
# Movie Title: Series 7: The Contenders (2001)
#
# Movie ID: 4226
# Movie Title: Memento (2000)
#
# Movie ID: 4239
# Movie Title: Blow (2001)
#
# Movie ID: 4246
# Movie Title: Bridget Jones's Diary (2001)
#
# Movie ID: 4252
# Movie Title: Circle, The (Dayereh) (2000)
#
# Movie ID: 4260
# Movie Title: Visit, The (2000)
#
# Movie ID: 4273
# Movie Title: Under the Sand (2000)
#
# Movie ID: 4308
# Movie Title: Moulin Rouge (2001)
#
# Movie ID: 4347
# Movie Title: Divided We Fall (Musíme si pomáhat) (2000)
#
# Movie ID: 4381
# Movie Title: Closet, The (Placard, Le) (2001)
#
# Movie ID: 4641
# Movie Title: Ghost World (2001)
#
# Movie ID: 4741
# Movie Title: Together (Tillsammans) (2000)
#
# Movie ID: 4765
# Movie Title: L.I.E. (2001)
#
# Movie ID: 4881
# Movie Title: Man Who Wasn't There, The (2001)
#
# Movie ID: 4896
# Movie Title: Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)
#
# Movie ID: 4902
# Movie Title: Devil's Backbone, The (Espinazo del diablo, El) (2001)
#
# Movie ID: 4967
# Movie Title: No Man's Land (2001)

# %%
for mid in [1,2,21,32,126]:
    print("User Index:", uid_to_idx[4])
    print("Movie Index:", mid_to_idx[mid])
    print("Value of matrix:", ratings_matrix[uid_to_idx[4],mid_to_idx[mid]])
    print()
# Out:
# User Index: 3
# Movie Index: 0
# Value of matrix: 0.0
#
# User Index: 3
# Movie Index: 481
# Value of matrix: 0.0
#
# User Index: 3
# Movie Index: 291
# Value of matrix: 1.0
#
# User Index: 3
# Movie Index: 292
# Value of matrix: 1.0
#
# User Index: 3
# Movie Index: 298
# Value of matrix: 1.0

# %% [markdown]
# **Q5**. Now that you have a `ratings_matrix` in the correct format, let's save it in pickle format:
# - Create a variable `dst_dir` corresponding to the path of the folder `data/netflix` located at the root of the repository
# - **Verify that this is the correct path**
# - Save the ratings_matrix in pickle (as `ratings_matrix.pkl`) in this corresponding directory

# %%
dst_dir = "./data/netflix"

# %%
import pickle
pickle.dump(ratings_matrix, open(dst_dir + "/ratings_matrix.pkl","wb"))

# %% [markdown]
# **Q6**. Save also all mappings objects into pickle (`idx_to_mid`, `mid_to_idx`, `uid_to_idx`, `idx_to_uid`) as it will be useful for later.

# %%
pickle.dump(idx_to_mid, open(dst_dir + "/idx_to_mid.pkl","wb"))
pickle.dump(mid_to_idx, open(dst_dir + "/mid_to_idx.pkl","wb"))
pickle.dump(uid_to_idx, open(dst_dir + "/uid_to_idx.pkl","wb"))
pickle.dump(idx_to_uid, open(dst_dir + "/idx_to_uid.pkl","wb"))

# %% [markdown]
# Up to next challenge now! 🍿
